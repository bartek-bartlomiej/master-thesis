# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))

del os, sys

# %%
from tests.gate_experiments.controlled_adder import Experiment

# %%
n = 5
experiment = Experiment(n)

# %%
experiment._qregs_spec
# Out:
# {'ctrl': 1, 'x': 5, 'y': 5}

# %%
values = dict(ctrl=0b1, x=10, y=7)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl', fold=-1)

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'10001 01010 1': 1}

# %%
n = 2
experiment = Experiment(2)

# %%
experiment._qregs_spec
# Out:
# {'ctrl': 1, 'x': 2, 'y': 2}

# %%
values = dict(ctrl=0b0, x=1, y=2)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl', fold=-1)

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'10 01 0': 1}

# %%
n = 1
experiment = Experiment(1)

# %%
values = dict(ctrl=0b0, x=1, y=1)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl', fold=-1)

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'1 1 0': 1}
