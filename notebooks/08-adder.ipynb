# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))

del os, sys

# %%
from tests.haner.gate_experiments.adder import Experiment

# %%
n = 5
experiment = Experiment(n)

# %%
experiment._qregs_spec
# Out:
# {'x': 5, 'y': 5}

# %%
values = dict(x=10, y=7)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl', fold=-1)

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'10001 01010': 1}

# %%
n = 2
experiment = Experiment(2)

# %%
experiment._qregs_spec
# Out:
# {'x': 2, 'y': 2}

# %%
values = dict(x=1, y=2)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl', fold=-1)

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'11 01': 1}

# %%
n = 1
experiment = Experiment(1)

# %%
values = dict(x=1, y=1)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl', fold=-1)

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'0 1': 1}
