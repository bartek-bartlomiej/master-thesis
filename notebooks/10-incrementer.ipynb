# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))

del os, sys

# %%
from tests.gate_experiments.incrementer import Experiment

# %%
n = 5
experiment = Experiment(n)

# %%
experiment._qregs_spec
# Out:
# {'x': 5, 'g': 5}

# %%
values = dict(x=10, g=7)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl', fold=-1)

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'00111 01011': 1}

# %%
n = 2
experiment = Experiment(2)

# %%
experiment._qregs_spec
# Out:
# {'x': 2, 'g': 2}

# %%
values = dict(x=1, g=2)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl', fold=-1)

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'10 10': 1}

# %%
n = 1
experiment = Experiment(1)

# %%
values = dict(x=1, g=1)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.decompose().draw(output='mpl', fold=-1)

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'1 0': 1}
