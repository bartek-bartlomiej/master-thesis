# %%
import os, sys
sys.path.insert(0, os.path.abspath('..'))

del os, sys

# %%
from tests.gate_experiments.modulo_exponentiation import Experiment

# %%
constant = 11
n = 4
N = 13
experiment = Experiment(constant, N, n)

# %%
experiment._qregs_spec
# Out:
# {'x': 8, 'y': 4, 'aux': 5}

# %%
values = dict(ctrl=0b1, x=10, y=1)

# %%
qc = experiment._construct_circuit(values, 'qc')

# %%
qc.draw(output='mpl')

# %%
qc.decompose().draw(output='mpl', fold=-1)

# %%
res = experiment.run(values, 'demo')
res.get_counts('demo')
# Out:
# {'00000 1010 00001010': 1}

# %%
pow(constant, 10, mod=N)
# Out:
# 10
